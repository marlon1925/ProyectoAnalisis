# %%
pip install pandas
# Out:
# ...
#
# ...
# [notice] A new release of pip available: 22.3 -> 23.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd

# %%
df0 = pd.read_csv('enemdu_consumidor_2020_12.csv',delimiter=';')

# %%
df0
# Out:
#       area  ciudad  conglomerado  panelm  vivienda  hogar  c01  c02  c03  \
# 0        1   10150           503       9         1      1    2    2    2
# 1        1   10150           503       9         2      1    3    2    2
# 2        1   10150           503       9         3      1    3    1    3
# 3        1   10150           503       9         4      1    3    1    2
# 4        1   10150           503       9         5      1    2    2    2
# ...    ...     ...           ...     ...       ...    ...  ...  ...  ...
# 8751     1  240350          1406       5         3      1    2    3    2
# 8752     1  240350          1406       5         4      1    3    3    2
# 8753     1  240350          1406       5         5      1    2    2    2
# 8754     1  240350          1406       5         6      1    2    2    3
# 8755     1  240350          1406       5         7      1    3    2    2
#
#       c04a  ...  c18  c19  c20a  c21a           upm        id_vivienda  \
# ...

# %%
pip install couchdb
# Out:
# ...
# [notice] A new release of pip available: 22.3 -> 23.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import couchdb

# %%
server=couchdb.Server("http://melani:12345@localhost:5984/")

# %%
db=server['consumidor']

# %%
data = df0.to_dict(orient='records')
for doc in data:
    db.save(doc)

# %%
df1 = pd.read_csv('enemdu_vivienda_hogar_2020_12.csv',delimiter=';')

# %%
df1
# Out:
#       area  ciudad  conglomerado  panelm  vivienda  hogar  vi01  vi02  vi03a  \
# 0        1   10150           503       9         1      1     1     1      4
# 1        1   10150           503       9         2      1     1     2      6
# 2        1   10150           503       9         3      1     1     2      2
# 3        1   10150           503       9         4      1     1     1      3
# 4        1   10150           503       9         5      1     1     2      1
# ...    ...     ...           ...     ...       ...    ...   ...   ...    ...
# 8751     1  240350          1406       5         3      1     1     1      1
# 8752     1  240350          1406       5         4      1     1     1      2
# 8753     1  240350          1406       5         5      1     1     1      2
# 8754     1  240350          1406       5         6      1     1     1      2
# 8755     1  240350          1406       5         7      1     1     1      2
#
# ...

# %%
db=server['vivienda']

# %%
data = df1.to_dict(orient='records')
for doc in data:
    db.save(doc)

# %%
df2 = pd.read_csv('enemdu_persona_2020_12.csv',delimiter=';')
# Out:
# C:\Users\PC\AppData\Local\Temp\ipykernel_1960\3730821038.py:1: DtypeWarning: Columns (162) have mixed types. Specify dtype option on import or set low_memory=False.
#   df2 = pd.read_csv('enemdu_persona_2020_12.csv',delimiter=';')

# %%
df2
# Out:
#        area  ciudad  conglomerado  panelm  vivienda  hogar  p01  p02  p03  \
# 0         2  200250            22       5         2      1    1    2   55
# 1         2  200250            22       5         2      1    2    1   39
# 2         2  200250            22       5         3      1    1    2   30
# 3         2  200250            22       5         3      1    2    1   33
# 4         2  200250            22       5         3      1    3    2    0
# ...     ...     ...           ...     ...       ...    ...  ...  ...  ...
# 30641     2   50150        910102       9         9      1    3    1   21
# 30642     2   50150        910102       9         9      1    4    1   17
# 30643     2   50150        910102       9         9      1    5    1   15
# 30644     2   50150        910102       9         9      1    6    2    7
# 30645     2   50150        910102       9         9      1    7    2   20
#
#        p04  ...             ingpc  pobreza epobreza nnivins estrato  \
# ...

# %%
db=server['persona']

# %%
data = df2.to_dict(orient='records')
for doc in data:
    db.save(doc)
