# %%
pip install pandas
# Out:
# Note: you may need to restart the kernel to use updated packages.Requirement already satisfied: pandas in c:\users\pc\appdata\local\programs\python\python311\lib\site-packages (1.5.3)
# ...
# [notice] A new release of pip available: 22.3 -> 23.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd

# %%
df = pd.read_csv('EDV_2020.csv',delimiter=';')

# %%
df
# Out:
#        prov_insc  cant_insc  parr_insc  anio_insc  mes_insc  dia_insc  \
# 0             17       1701     170112       2020         6        30
# 1              9        901      90110       2020         1         3
# 2              2        201      20101       2020         9        24
# 3              7        701      70102       2020         3        13
# 4              7        701      70102       2020         8        26
# ...          ...        ...        ...        ...       ...       ...
# 14563         12       1205     120502       2020         3         5
# 14564         12       1205     120502       2020         3         3
# 14565         12       1205     120502       2020         2        28
# 14566         12       1205     120502       2020         2        20
# 14567          9        901      90112       2020         9        13
#
#       fecha_insc  anio_div  mes_div  dia_div  ...  fecha_nac2  edad_2  \
# ...

# %%
pip install couchdb
# Out:
# Note: you may need to restart the kernel to use updated packages.Requirement already satisfied: couchdb in c:\users\pc\appdata\local\programs\python\python311\lib\site-packages (1.2)
# [notice] A new release of pip available: 22.3 -> 23.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import couchdb

# %%
server=couchdb.Server("http://melani:12345@localhost:5984/")

# %%
db=server['proyecto']

# %%
data = df.to_dict(orient='records')
for doc in data:
    db.save(doc)
