# %%
pip install couchdb
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install tweepy
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install tweepy --upgrade
# Out:
# ...
#   Using cached tweepy-4.12.1-py3-none-any.whl (101 kB)
# ...
#   Attempting uninstall: tweepy
#     Found existing installation: tweepy 3.10.0
#     Uninstalling tweepy-3.10.0:
#       Successfully uninstalled tweepy-3.10.0
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install tweepy==3.10.0
# Out:
# ...
#   Using cached tweepy-3.10.0-py2.py3-none-any.whl (30 kB)
# ...
#   Attempting uninstall: tweepy
#     Found existing installation: tweepy 4.12.1
#     Uninstalling tweepy-4.12.1:
#       Successfully uninstalled tweepy-4.12.1
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import couchdb
from tweepy import Stream
from tweepy import OAuthHandler
from tweepy.streaming import StreamListener
import json

# %%
#API ########################
ckey = "g14Pm5PKampiiaDgxydyzUk6E"
csecret = "m2n3iLh4Mom4go7FB135Xr39KE5zQQIVaXvqP3SXSM5YVxI37Y"
atoken = "1415798278688497666-AorfXm1bjdFMlHSLqkScIJ5S9350wH"
asecret = "gBQQPnjcbIQg6AHkNqJL3qEQABqlq8N5qaRpZki268fu1"
#####################################


class listener(StreamListener):
    def __init__(self):
        super().__init__()
        self.saved_docs = 0

    def on_data(self, data):
        if self.saved_docs < 200:
            dictTweet = json.loads(data)
            try:
                dictTweet["_id"] = str(dictTweet['id'])
                doc = db.save(dictTweet)
                tweet_date = dictTweet['created_at']
                tweet_location = dictTweet['user']['location']
                tweet_text = dictTweet['text']
                tweet_user = dictTweet['user']['screen_name']
                tweet_retweets = dictTweet['retweet_count']
                print(f"Fecha: {tweet_date}, Ubicación: {tweet_location}, Texto: {tweet_text}, Usuario: {tweet_user}, Retweets: {tweet_retweets}")
                self.saved_docs += 1
            except:
                print ("Already exists")
                pass
            return True
        else:
            # Detener el stream cuando se han guardado 10 documentos
            twitterStream.disconnect()
            return False

    def on_error(self, status):
        print (status)

auth = OAuthHandler(ckey, csecret)
auth.set_access_token(atoken, asecret)
twitterStream = Stream(auth, listener())

'''========couchdb'=========='''
server = couchdb.Server('http://admin:admin@localhost:5984/')
try:
    db = server.create('bd_trabajo')
except:
    db = server['bd_trabajo']

'''===============LOCATIONS=============='''    
twitterStream.filter(track=['empleo','puestos de trabajo'])
# Out:
# Fecha: Thu Mar 02 18:50:30 +0000 2023, Ubicación: Tomares (Sevilla), Texto: RT @AlfredoLinacero: Cinco marcas sanluqueñas desfilan en la Semana de la Moda de Andalucía el próximo martes 7 de marzo a las 20 horas en…, Usuario: LinaceroCM, Retweets: 0
# Fecha: Thu Mar 02 18:50:30 +0000 2023, Ubicación: None, Texto: RT @Josesua18831259: #2Mar| 🇻🇪 📢 ¡ETIQUETA DEL DÍA! ▶️
#
# #ProducirEsIndependencia, Usuario: Sthefan20637486, Retweets: 0
# Fecha: Thu Mar 02 18:50:31 +0000 2023, Ubicación: Honduras, Texto: RT @SabasYury: Que obvio es cuando un político nunca a generado empleo y solo a sembrado cizaña.Sus propuestas son+Feriados +Impuestos+Gast…, Usuario: rbellino13, Retweets: 0
# Fecha: Thu Mar 02 18:50:33 +0000 2023, Ubicación: None, Texto: RT @VTVcanal8: #EMPLEO💻| ¡Únete a nuestro equipo de Multimedios VTV! 💻🙌
#
# Si te encuentras en la Gran Caracas y tienes habilidades para la c…, Usuario: Et2571625Torres, Retweets: 0
# ...
